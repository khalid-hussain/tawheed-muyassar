# %%
import pandas as pd

filename = 'hafsData_v18.csv'
mCSV = pd.read_csv(filename)

df = mCSV[["id","sora","sora_name_en", "sora_name_ar","aya_no", "aya_text","aya_text_emlaey"]]

def seeker(data, location):
    surah = data[data['sora'] == location[0]]

    if len(location) == 1:
        return surah
    if len(location) == 2:
        return surah[surah['aya_no'] == location[1]]
    elif len(location) == 3:
        return surah[(surah['aya_no'] >= location[1]) & (surah['aya_no'] <= location[2])]

# %%
location = [7,180]
result = ' '.join(seeker(df, location)['aya_text'])
result = result.replace('\xa0', 'nbsp')
print(result)
# Out:
# وَلِلَّهِ ٱلۡأَسۡمَآءُ ٱلۡحُسۡنَىٰ فَٱدۡعُوهُ بِهَاۖ وَذَرُواْ ٱلَّذِينَ يُلۡحِدُونَ فِيٓ أَسۡمَٰٓئِهِۦۚ سَيُجۡزَوۡنَ مَا كَانُواْ يَعۡمَلُونَnbsp١٨٠

# %%
location = [9,36];
result = ' '.join(seeker(df, location)['aya_text_emlaey'])
print(result)
# Out:
# إن عدة الشهور عند الله اثنا عشر شهرا في كتاب الله يوم خلق السموات والأرض منها أربعة حرم ذلك الدين القيم فلا تظلموا فيهن أنفسكم وقاتلوا المشركين كافة كما يقاتلونكم كافة واعلموا أن الله مع المتقين

# %%
X = 30
Y = 1
# mString = f"\RES{{{X}}}{{{Y}}}{{25}}{{TITLE}}"

# for x in range (1,30):
#     mString = f"\RES{{{X}}}{{{Y}}}{{25}}{{TITLE}}"
#     X = X + 1
#     Y = Y + 1
#     print(mString)

for x in range (1,31):
    print(f"# Juz {x}")
# Out:
# # Juz 1
# # Juz 2
# # Juz 3
# # Juz 4
# # Juz 5
# # Juz 6
# # Juz 7
# # Juz 8
# # Juz 9
# # Juz 10
# # Juz 11
# # Juz 12
# # Juz 13
# # Juz 14
# # Juz 15
# # Juz 16
# # Juz 17
# # Juz 18
# # Juz 19
# # Juz 20
# # Juz 21
# # Juz 22
# # Juz 23
# # Juz 24
# # Juz 25
# # Juz 26
# # Juz 27
# # Juz 28
# # Juz 29
# # Juz 30
